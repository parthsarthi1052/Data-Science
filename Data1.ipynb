# %% [markdown]
# <a href="https://colab.research.google.com/github/parthsarthi1052/Data-Science/blob/main/Data1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("write a number"))
print("even")
for i in range(1,a+1):
  if i%2==0:
    print(i,"\n")
print("odd")
for i in range(a+1):
  if i%2!=0:
    print(i,"\n")

# %%
a=int(input("number?"))
if a==0:
  print("none")
elif a%2==0:
  print("+ve")
else:
  print("-ve")

# %%
a=str(input())
if a=="mon":
  print("monday")
elif a=="tue":
  print("tuesday")
elif a=="wed":
  print("wednesay")
elif a=="thru":
  print("thrusday")
elif a=="fri":
  print("friday")
elif a=="sat":
  print("satruday")
else:
  print("weekend")

# %%
s=str(input("write the string"))
l=len(s)
x=0
for i in range(0,l//2):
  if s[i]!=s[l-i-1]:
    print("not a pallindrome")
    x=1
    break

if x==0:
  print("pallindrome")

# %%
s=str(input("write the string"))
l=len(s)
x=0
for i in range(0,l//2):
  if s[i]!=s[l-i-1]:
    print("not a pallindrome")
    x=1
    break

if x==0:
  print("pallindrome")
